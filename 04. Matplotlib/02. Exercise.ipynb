# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %%
# Import matplotlib.pyplot as plt and set %matplotlib inline 
# if you are using the jupyter notebook. What command do you 
# use if you aren't using the jupyter notebook?
import matplotlib.pyplot as plt
# %matplotlib inline
# plt.show() at the end of your plotting commands

# %%
# Exercise 1
# Follow along with these steps: 

# Create a figure object called fig using plt.figure()
# Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.
# Plot (x,y) on that axes and set the labels and titles to match the plot below:

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')
# Out:
# Text(0.5,1,'title')

# %%
# Exercise 2
# Create a figure object and put two axes on it, ax1 and ax2. 
# Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.
# Now plot (x,y) on both axes. And call your figure object to show it.

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(x, y)
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax2 = fig.add_axes([0.2, 0.5, 0.2, 0.2])
ax2.plot(x, y, c='r')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
# Out:
# Text(0,0.5,'y')

# %%
# Exercise 3
# Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]
# Now use x,y, and z arrays to recreate the plot below. 
# Notice the xlimits and y limits on the inserted plot:

# %%
fig = plt.figure()

ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(x, z, c='r')
ax1.set_xlabel('X')
ax1.set_ylabel('Z')

ax2 = fig.add_axes([0.2, 0.5, 0.4, 0.4])
ax2.plot(x, y)
ax2.set_xlim([20, 22])
ax2.set_ylim([30, 50])
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('zoom')
# Out:
# Text(0.5,1,'zoom')

# %%
# Exercise 4
# Use plt.subplots(nrows=1, ncols=2) to create the plot below.
# Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x, y, c='blue', lw=4, ls='--')

axes[1].plot(x, z, c='r', lw=2)

plt.tight_layout()

# %%
# See if you can resize the plot by adding the figsize() 
# argument in plt.subplots() by copying and pasting your previous code.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 2))

axes[0].plot(x, y, c='b', lw=4)

axes[1].plot(x, z, c='r', lw=2, ls='--')

plt.tight_layout()
